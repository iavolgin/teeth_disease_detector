# %%
import json
import numpy as np
import pandas as pd
import os
import sys
from pathlib import Path

ROOT = Path.cwd()
if not (ROOT / "pkg").exists():
    if (ROOT.parent / "pkg").exists():
        ROOT = ROOT.parent
    else:
        raise RuntimeError("Не найден корень репозитория (папка pkg)")

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from pkg.metadata import compute_metadata

pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)

# %%
ANNOTATIONS_DIR = ROOT / "experiments" / "data" / "labels"
OUTPUT_DIR = ROOT / "experiments" / "results" / "classification_dataset"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

OUTPUT_CSV = OUTPUT_DIR / "teeth_classification_dataset.csv"

print(f"Директория с аннотациями: {ANNOTATIONS_DIR}")
print(f"Директория для результатов: {OUTPUT_DIR}")
print(f"Выходной файл: {OUTPUT_CSV}")
# Out:
# Директория с аннотациями: ../experiments/data/labels
# Директория для результатов: ../experiments/results/classification_dataset
# Выходной файл: ../experiments/results/classification_dataset\teeth_classification_dataset.csv

# %%
def polygon_to_bbox(points):
    """
    Конвертирует полигон в bounding box.
    :param points: Список точек [[x1, y1], [x2, y2], ...]
    :return: [x_min, y_min, x_max, y_max]
    """
    points = np.array(points)
    x_min = np.min(points[:, 0])
    y_min = np.min(points[:, 1])
    x_max = np.max(points[:, 0])
    y_max = np.max(points[:, 1])
    return [x_min, y_min, x_max, y_max]

# %%
json_files = list(Path(ANNOTATIONS_DIR).glob("*.json"))

print(f"Найдено файлов с аннотациями: {len(json_files)}")
# Out:
# Найдено файлов с аннотациями: 2066

# %%
all_records = []

for json_path in json_files:
    try:
        with open(json_path, 'r', encoding='utf-8') as f:
            annotation_data = json.load(f)
        
        img_width = annotation_data.get('imageWidth', 2440)
        img_height = annotation_data.get('imageHeight', 1280)
        
        bboxes = []
        labels = []
        
        for shape in annotation_data.get('shapes', []):
            tooth_label = shape['label']
            points = shape['points']
            
            bbox = polygon_to_bbox(points)
            
            bboxes.append(bbox)
            labels.append(tooth_label)
        
        if len(bboxes) == 0:
            print(f"Предупреждение: {json_path.name} - нет зубов")
            continue
        
        metadata_list = compute_metadata(bboxes, image_width=img_width)
        
        for i, meta in enumerate(metadata_list):
            record = {
                'tooth_label': labels[i],
                
                'quadrant': meta['quadrant'],
                'x_norm': meta['x_norm'],
                'y_norm': meta['y_norm'],
                'aspect_ratio': meta['aspect_ratio'],
                'neighbours_right': meta['neighbours_right'],
                'neighbours_top': meta['neighbours_top'],
            }
            all_records.append(record)
        
        print(f"Обработано: {json_path.name} - {len(bboxes)} зубов")
        
    except Exception as e:
        print(f"Ошибка при обработке {json_path.name}: {e}")
        continue

print(f"\nВсего собрано записей: {len(all_records)}")
# Out:
# Обработано: 1000.json - 32 зубов
# Обработано: 1001.json - 28 зубов
# Обработано: 1002.json - 28 зубов
# Обработано: 1003.json - 26 зубов
# Обработано: 1004.json - 26 зубов
# Обработано: 1005.json - 26 зубов
# Обработано: 1006.json - 21 зубов
# Обработано: 1007.json - 26 зубов
# Обработано: 1008.json - 24 зубов
# Обработано: 1009.json - 24 зубов
# Обработано: 1010.json - 22 зубов
# Обработано: 1011.json - 22 зубов
# Обработано: 1012.json - 22 зубов
# Обработано: 1013.json - 22 зубов
# Обработано: 1014.json - 29 зубов
# Обработано: 1015.json - 29 зубов
# Обработано: 1016.json - 8 зубов
# Обработано: 1017.json - 8 зубов
# Обработано: 1018.json - 8 зубов
# Обработано: 1019.json - 8 зубов
# Обработано: 1020.json - 28 зубов
# Обработано: 1021.json - 28 зубов
# Обработано: 1022.json - 25 зубов
# Обработано: 1023.json - 25 зубов
# Обработано: 1024.json - 23 зубов
# Обработано: 1025.json - 23 зубов
# Обработано: 1026.json - 23 зубов
# Обработано: 1027.json - 23 зубов
# Обработано: 1028.json - 23 зубов
# Обработано: 1029.json - 23 зубов
# Обработано: 1030.json - 23 зубов
# Обработано: 1031.json - 23 зубов
# Обработано: 1032.json - 23 зубов
# Обработано: 1033.json - 26 зубов
# Обработано: 1034.json - 22 зубов
# Обработано: 1035.json - 28 зубов
# Обработано: 1036.json - 25 зубов
# Обработано: 1037.json - 25 зубов
# Обработано: 1038.json - 22 зубов
# Обработано: 1039.json - 26 зубов
# Обработано: 1040.json - 26 зубов
# Обработано: 1041.json - 24 зубов
# Обработано: 1042.json - 23 зубов
# Обработано: 1043.json - 23 зубов
# Обработано: 1044.json - 23 зубов
# Обработано: 1045.json - 25 зубов
# Обработано: 1046.json - 26 зубов
# Обработано: 1047.json - 26 зубов
# Обработано: 1048.json - 25 зубов
# Обработано: 1049.json - 24 зубов
# Обработано: 1050.json - 19 зубов
# Обработано: 1051.json - 18 зубов
# Обработано: 1052.json - 18 зубов
# Обработано: 1053.json - 18 зубов
# Обработано: 1054.json - 26 зубов
# Обработано: 1055.json - 26 зубов
# Обработано: 1056.json - 26 зубов
# Обработано: 1057.json - 27 зубов
# Обработано: 1058.json - 23 зубов
# Обработано: 1059.json - 25 зубов
# Обработано: 1060.json - 22 зубов
# Обработано: 1061.json - 27 зубов
# Обработано: 1062.json - 24 зубов
# Обработано: 1063.json - 24 зубов
# Обработано: 1064.json - 23 зубов
# Обработано: 1065.json - 23 зубов
# Обработано: 1066.json - 29 зубов
# Обработано: 1067.json - 28 зубов
# Обработано: 1068.json - 28 зубов
# Обработано: 1069.json - 28 зубов
# Обработано: 1070.json - 17 зубов
# Обработано: 1071.json - 17 зубов
# Обработано: 1072.json - 21 зубов
# Обработано: 1073.json - 21 зубов
# Обработано: 1074.json - 21 зубов
# Обработано: 1075.json - 21 зубов
# Обработано: 1076.json - 21 зубов
# Обработано: 1077.json - 23 зубов
# Обработано: 1078.json - 23 зубов
# Обработано: 1079.json - 29 зубов
# Обработано: 1080.json - 29 зубов
# Обработано: 1081.json - 20 зубов
# Обработано: 1082.json - 28 зубов
# Обработано: 1083.json - 19 зубов
# Обработано: 1084.json - 19 зубов
# Обработано: 1085.json - 19 зубов
# Обработано: 1086.json - 19 зубов
# Обработано: 1087.json - 30 зубов
# Обработано: 1088.json - 27 зубов
# Обработано: 1089.json - 24 зубов
# Обработано: 1090.json - 23 зубов
# Обработано: 1091.json - 23 зубов
# Обработано: 1092.json - 23 зубов
# Обработано: 1093.json - 22 зубов
# Обработано: 1094.json - 22 зубов
# Обработано: 1095.json - 19 зубов
# Обработано: 1096.json - 19 зубов
# Обработано: 1097.json - 25 зубов
# Обработано: 1098.json - 25 зубов
# Обработано: 1099.json - 23 зубов
# Обработано: 1100.json - 12 зубов
# Обработано: 2000.json - 25 зубов
# Обработано: 2001.json - 31 зубов
# Обработано: 2002.json - 26 зубов
# Обработано: 2003.json - 26 зубов
# Обработано: 2004.json - 25 зубов
# Обработано: 2005.json - 25 зубов
# Обработано: 2006.json - 26 зубов
# Обработано: 2007.json - 20 зубов
# Обработано: 2008.json - 19 зубов
# Обработано: 2009.json - 26 зубов
# Обработано: 2010.json - 19 зубов
# Обработано: 2011.json - 19 зубов
# Обработано: 2012.json - 31 зубов
# Обработано: 2013.json - 18 зубов
# Обработано: 2014.json - 18 зубов
# Обработано: 2015.json - 28 зубов
# Обработано: 2016.json - 25 зубов
# Обработано: 2017.json - 25 зубов
# Обработано: 2018.json - 27 зубов
# Обработано: 2019.json - 27 зубов
# Обработано: 2020.json - 28 зубов
# Обработано: 2021.json - 28 зубов
# Обработано: 2022.json - 25 зубов
# Обработано: 2023.json - 25 зубов
# Обработано: 2024.json - 28 зубов
# Обработано: 2025.json - 24 зубов
# Обработано: 2026.json - 24 зубов
# Обработано: 2027.json - 24 зубов
# Обработано: 2028.json - 29 зубов
# Обработано: 2029.json - 29 зубов
# Обработано: 2030.json - 31 зубов
# Обработано: 2031.json - 28 зубов
# Обработано: 2032.json - 28 зубов
# Обработано: 2033.json - 25 зубов
# Обработано: 2034.json - 25 зубов
# Обработано: 2035.json - 23 зубов
# Обработано: 2036.json - 23 зубов
# Обработано: 2037.json - 28 зубов
# Обработано: 2038.json - 27 зубов
# Обработано: 2039.json - 26 зубов
# Обработано: 2040.json - 29 зубов
# Обработано: 2041.json - 28 зубов
# Обработано: 2042.json - 26 зубов
# Обработано: 2043.json - 29 зубов
# Обработано: 2044.json - 26 зубов
# Обработано: 2045.json - 25 зубов
# Обработано: 2046.json - 25 зубов
# Обработано: 2047.json - 21 зубов
# Обработано: 2051.json - 30 зубов
# Обработано: 2052.json - 17 зубов
# Обработано: 2053.json - 16 зубов
# Обработано: 2054.json - 17 зубов
# Обработано: 2055.json - 27 зубов
# Обработано: 2056.json - 13 зубов
# Обработано: 2057.json - 31 зубов
# Обработано: 2058.json - 27 зубов
# Обработано: 2059.json - 27 зубов
# Обработано: 2060.json - 27 зубов
# Обработано: 2061.json - 31 зубов
# Обработано: 2062.json - 31 зубов
# Обработано: 2063.json - 23 зубов
# Обработано: 2064.json - 25 зубов
# Обработано: 2065.json - 24 зубов
# Обработано: 2066.json - 24 зубов
# Обработано: 2067.json - 27 зубов
# Обработано: 2068.json - 20 зубов
# Обработано: 2069.json - 20 зубов
# Обработано: 2070.json - 24 зубов
# Обработано: 2071.json - 29 зубов
# Обработано: 2072.json - 25 зубов
# Обработано: 2073.json - 24 зубов
# Обработано: 2074.json - 26 зубов
# Обработано: 2075.json - 28 зубов
# Обработано: 2076.json - 29 зубов
# Обработано: 2077.json - 25 зубов
# Обработано: 2078.json - 28 зубов
# Обработано: 2079.json - 28 зубов
# Обработано: 2080.json - 24 зубов
# Обработано: 2081.json - 24 зубов
# Обработано: 2082.json - 24 зубов
# Обработано: 2084.json - 26 зубов
# Обработано: 2085.json - 26 зубов
# Обработано: 2086.json - 26 зубов
# Обработано: 2087.json - 31 зубов
# Обработано: 2088.json - 28 зубов
# Обработано: 2089.json - 26 зубов
# Обработано: 2090.json - 25 зубов
# Обработано: 2091.json - 25 зубов
# Обработано: 2092.json - 25 зубов
# Обработано: 2093.json - 31 зубов
# Обработано: 2094.json - 27 зубов
# Обработано: 2095.json - 27 зубов
# Обработано: 2096.json - 26 зубов
# Обработано: 2097.json - 24 зубов
# Обработано: 2098.json - 28 зубов
# Обработано: 2099.json - 28 зубов
# Обработано: 2100.json - 23 зубов
# Обработано: 2101.json - 26 зубов
# Обработано: 2102.json - 24 зубов
# Обработано: 2103.json - 24 зубов
# Обработано: 2104.json - 25 зубов
# Обработано: 2105.json - 26 зубов
# Обработано: 2106.json - 26 зубов
# Обработано: 2107.json - 21 зубов
# Обработано: 2109.json - 20 зубов
# Обработано: 2110.json - 20 зубов
# Обработано: 2111.json - 20 зубов
# Обработано: 2112.json - 20 зубов
# Обработано: 2113.json - 25 зубов
# Обработано: 2114.json - 25 зубов
# Обработано: 2115.json - 25 зубов
# Обработано: 2116.json - 25 зубов
# Обработано: 2117.json - 25 зубов
# Обработано: 2118.json - 25 зубов
# Обработано: 2119.json - 26 зубов
# Обработано: 2120.json - 26 зубов
# Обработано: 2121.json - 29 зубов
# Обработано: 2122.json - 25 зубов
# Обработано: 2123.json - 25 зубов
# Обработано: 2124.json - 29 зубов
# Обработано: 2125.json - 28 зубов
# Обработано: 2126.json - 26 зубов
# Обработано: 2127.json - 26 зубов
# Обработано: 2128.json - 25 зубов
# Обработано: 2129.json - 25 зубов
# Обработано: 2130.json - 29 зубов
# Обработано: 2131.json - 29 зубов
# Обработано: 2132.json - 29 зубов
# Обработано: 2133.json - 29 зубов
# Обработано: 2134.json - 31 зубов
# Обработано: 2135.json - 27 зубов
# Обработано: 2136.json - 26 зубов
# Обработано: 2137.json - 29 зубов
# Обработано: 2138.json - 28 зубов
# Обработано: 2139.json - 24 зубов
# Обработано: 2140.json - 24 зубов
# Обработано: 2141.json - 25 зубов
# Обработано: 2142.json - 20 зубов
# Обработано: 2143.json - 20 зубов
# Обработано: 2144.json - 20 зубов
# Обработано: 2145.json - 27 зубов
# Обработано: 2146.json - 27 зубов
# Обработано: 2148.json - 29 зубов
# Обработано: 2149.json - 23 зубов
# Обработано: 2150.json - 23 зубов
# Обработано: 2151.json - 23 зубов
# Обработано: 2152.json - 23 зубов
# Обработано: 2153.json - 26 зубов
# Обработано: 2154.json - 16 зубов
# Обработано: 2155.json - 16 зубов
# Обработано: 2156.json - 16 зубов
# Обработано: 2157.json - 31 зубов
# Обработано: 2158.json - 25 зубов
# Обработано: 2159.json - 25 зубов
# Обработано: 2160.json - 25 зубов
# Обработано: 2161.json - 23 зубов
# Обработано: 2162.json - 23 зубов
# Обработано: 2163.json - 23 зубов
# Обработано: 2164.json - 23 зубов
# Обработано: 2165.json - 25 зубов
# Обработано: 2166.json - 28 зубов
# Обработано: 2167.json - 31 зубов
# Обработано: 2168.json - 29 зубов
# Обработано: 2169.json - 25 зубов
# Обработано: 2170.json - 32 зубов
# Обработано: 2172.json - 22 зубов
# Обработано: 2173.json - 22 зубов
# Обработано: 2174.json - 23 зубов
# Обработано: 2175.json - 30 зубов
# Обработано: 2176.json - 30 зубов
# Обработано: 2177.json - 30 зубов
# Обработано: 2178.json - 29 зубов
# Обработано: 2179.json - 27 зубов
# Обработано: 2180.json - 27 зубов
# Обработано: 2181.json - 27 зубов
# Обработано: 2182.json - 27 зубов
# Обработано: 2183.json - 30 зубов
# Обработано: 2184.json - 25 зубов
# Обработано: 2185.json - 25 зубов
# Обработано: 2186.json - 25 зубов
# Обработано: 2187.json - 25 зубов
# Обработано: 2188.json - 27 зубов
# Обработано: 2189.json - 27 зубов
# Обработано: 2190.json - 27 зубов
# Обработано: 2191.json - 24 зубов
# Обработано: 2192.json - 24 зубов
# Обработано: 2193.json - 24 зубов
# Обработано: 2194.json - 22 зубов
# Обработано: 2195.json - 30 зубов
# Обработано: 2196.json - 30 зубов
# Обработано: 2197.json - 31 зубов
# Обработано: 2198.json - 25 зубов
# Обработано: 2199.json - 26 зубов
# Обработано: 2200.json - 26 зубов
# Обработано: 4200.json - 29 зубов
# Обработано: 4201.json - 32 зубов
# Обработано: 4202.json - 29 зубов
# Обработано: 4203.json - 25 зубов
# Обработано: 4204.json - 25 зубов
# Обработано: 4205.json - 31 зубов
# Обработано: 4206.json - 30 зубов
# Обработано: 4208.json - 28 зубов
# Обработано: 4209.json - 30 зубов
# Обработано: 4210.json - 28 зубов
# Обработано: 4211.json - 28 зубов
# Обработано: 4212.json - 20 зубов
# Обработано: 4213.json - 16 зубов
# Обработано: 4214.json - 27 зубов
# Обработано: 4215.json - 31 зубов
# Обработано: 4216.json - 31 зубов
# Обработано: 4217.json - 32 зубов
# Обработано: 4218.json - 23 зубов
# Обработано: 4219.json - 32 зубов
# Обработано: 4220.json - 32 зубов
# Обработано: 4221.json - 32 зубов
# Обработано: 4222.json - 31 зубов
# Обработано: 4223.json - 32 зубов
# Обработано: 4224.json - 10 зубов
# Обработано: 4225.json - 30 зубов
# Обработано: 4226.json - 29 зубов
# Обработано: 4227.json - 31 зубов
# Обработано: 4228.json - 24 зубов
# Обработано: 4229.json - 32 зубов
# Обработано: 4230.json - 32 зубов
# Обработано: 4231.json - 23 зубов
# Обработано: 4232.json - 28 зубов
# Обработано: 4233.json - 28 зубов
# Обработано: 4234.json - 29 зубов
# Обработано: 4235.json - 30 зубов
# Обработано: 4236.json - 32 зубов
# Обработано: 4237.json - 32 зубов
# Обработано: 4238.json - 29 зубов
# Обработано: 4239.json - 27 зубов
# Обработано: 4240.json - 29 зубов
# Обработано: 4241.json - 28 зубов
# Обработано: 4242.json - 29 зубов
# Обработано: 4244.json - 14 зубов
# Обработано: 4245.json - 32 зубов
# Обработано: 4246.json - 28 зубов
# Обработано: 4247.json - 27 зубов
# Обработано: 4248.json - 29 зубов
# Обработано: 4249.json - 28 зубов
# Обработано: 4250.json - 27 зубов
# Обработано: 4251.json - 32 зубов
# Обработано: 4252.json - 34 зубов
# Обработано: 4253.json - 32 зубов
# Обработано: 4254.json - 23 зубов
# Обработано: 4255.json - 28 зубов
# Обработано: 4256.json - 29 зубов
# Обработано: 4257.json - 28 зубов
# Обработано: 4258.json - 32 зубов
# Обработано: 4259.json - 30 зубов
# Обработано: 4260.json - 32 зубов
# Обработано: 4261.json - 28 зубов
# Обработано: 4262.json - 31 зубов
# Обработано: 4263.json - 31 зубов
# Обработано: 4264.json - 27 зубов
# Обработано: 4265.json - 32 зубов
# Обработано: 4266.json - 32 зубов
# Обработано: 4267.json - 31 зубов
# Обработано: 4268.json - 25 зубов
# Обработано: 4269.json - 22 зубов
# Обработано: 4270.json - 27 зубов
# Обработано: 4271.json - 32 зубов
# Обработано: 4272.json - 31 зубов
# Обработано: 4273.json - 31 зубов
# Обработано: 4274.json - 29 зубов
# Обработано: 4275.json - 26 зубов
# Обработано: 4276.json - 27 зубов
# Обработано: 4277.json - 31 зубов
# Обработано: 4278.json - 31 зубов
# Обработано: 4279.json - 22 зубов
# Обработано: 4280.json - 23 зубов
# Обработано: 4281.json - 27 зубов
# Обработано: 4282.json - 30 зубов
# Обработано: 4283.json - 28 зубов
# Обработано: 4284.json - 28 зубов
# Обработано: 4285.json - 29 зубов
# Обработано: 4286.json - 27 зубов
# Обработано: 4287.json - 32 зубов
# Обработано: 4288.json - 30 зубов
# Обработано: 4289.json - 29 зубов
# Обработано: 4290.json - 32 зубов
# Обработано: 4291.json - 30 зубов
# Обработано: 4292.json - 32 зубов
# Обработано: 4294.json - 29 зубов
# Обработано: 4295.json - 31 зубов
# Обработано: 4296.json - 27 зубов
# Обработано: 4297.json - 27 зубов
# Обработано: 4298.json - 32 зубов
# Обработано: 4299.json - 25 зубов
# Обработано: 4300.json - 14 зубов
# Обработано: 4301.json - 31 зубов
# Обработано: 4302.json - 32 зубов
# Обработано: 4303.json - 26 зубов
# Обработано: 4304.json - 28 зубов
# Обработано: 4306.json - 28 зубов
# Обработано: 4307.json - 30 зубов
# Обработано: 4308.json - 26 зубов
# Обработано: 4309.json - 28 зубов
# Обработано: 4310.json - 26 зубов
# Обработано: 4311.json - 32 зубов
# Обработано: 4312.json - 31 зубов
# Обработано: 4313.json - 24 зубов
# Обработано: 4314.json - 32 зубов
# Обработано: 4315.json - 32 зубов
# Обработано: 4316.json - 30 зубов
# Обработано: 4317.json - 30 зубов
# Обработано: 4318.json - 29 зубов
# Обработано: 4320.json - 32 зубов
# Обработано: 4322.json - 28 зубов
# Обработано: 4323.json - 29 зубов
# Обработано: 4324.json - 26 зубов
# Обработано: 4325.json - 28 зубов
# Обработано: 4328.json - 28 зубов
# Обработано: 4329.json - 30 зубов
# Обработано: 4330.json - 32 зубов
# Обработано: 4331.json - 31 зубов
# Обработано: 4332.json - 30 зубов
# Обработано: 4333.json - 29 зубов
# Обработано: 4334.json - 31 зубов
# Обработано: 4336.json - 29 зубов
# Обработано: 4337.json - 29 зубов
# Обработано: 4338.json - 28 зубов
# Обработано: 4339.json - 32 зубов
# Обработано: 4340.json - 29 зубов
# Обработано: 4341.json - 29 зубов
# Обработано: 4342.json - 32 зубов
# Обработано: 4343.json - 32 зубов
# Обработано: 4344.json - 30 зубов
# Обработано: 4345.json - 32 зубов
# Обработано: 4346.json - 27 зубов
# Обработано: 4347.json - 29 зубов
# Обработано: 4349.json - 32 зубов
# Обработано: 4350.json - 32 зубов
# Обработано: 4351.json - 32 зубов
# Обработано: 4353.json - 29 зубов
# Обработано: 4354.json - 31 зубов
# Обработано: 4355.json - 29 зубов
# Обработано: 4356.json - 30 зубов
# Обработано: 4357.json - 27 зубов
# Обработано: 4358.json - 29 зубов
# Обработано: 4359.json - 28 зубов
# Обработано: 4360.json - 30 зубов
# Обработано: 4362.json - 31 зубов
# Обработано: 4363.json - 29 зубов
# Обработано: 4364.json - 27 зубов
# Обработано: 4365.json - 29 зубов
# Обработано: 4366.json - 32 зубов
# Обработано: 4368.json - 30 зубов
# Обработано: 4369.json - 25 зубов
# Обработано: 4371.json - 31 зубов
# Обработано: 4372.json - 24 зубов
# Обработано: 4373.json - 31 зубов
# Обработано: 4374.json - 32 зубов
# Обработано: 4376.json - 32 зубов
# Обработано: 4378.json - 31 зубов
# Обработано: 4379.json - 28 зубов
# Обработано: 4380.json - 31 зубов
# Обработано: 4381.json - 20 зубов
# Обработано: 4382.json - 31 зубов
# Обработано: 4384.json - 30 зубов
# Обработано: 4385.json - 29 зубов
# Обработано: 4386.json - 28 зубов
# Обработано: 4387.json - 30 зубов
# Обработано: 4389.json - 32 зубов
# Обработано: 4390.json - 28 зубов
# Обработано: 4392.json - 23 зубов
# Обработано: 4393.json - 24 зубов
# Обработано: 4394.json - 28 зубов
# Обработано: 4395.json - 28 зубов
# Обработано: 4396.json - 28 зубов
# Обработано: 4397.json - 29 зубов
# Обработано: 4398.json - 30 зубов
# Обработано: 4400.json - 32 зубов
# Обработано: 4402.json - 31 зубов
# Обработано: 4403.json - 32 зубов
# Обработано: 4404.json - 32 зубов
# Обработано: 4405.json - 30 зубов
# Обработано: 4409.json - 32 зубов
# Обработано: 4410.json - 32 зубов
# Обработано: 4411.json - 26 зубов
# Обработано: 4412.json - 30 зубов
# Обработано: 4413.json - 29 зубов
# Обработано: 4414.json - 31 зубов
# Обработано: 4415.json - 30 зубов
# Обработано: 4416.json - 30 зубов
# Обработано: 4417.json - 32 зубов
# Обработано: 4418.json - 31 зубов
# Обработано: 4419.json - 26 зубов
# Обработано: 4421.json - 32 зубов
# Обработано: 4422.json - 24 зубов
# Обработано: 4423.json - 24 зубов
# Обработано: 4425.json - 31 зубов
# Обработано: 4427.json - 31 зубов
# Обработано: 4428.json - 28 зубов
# Обработано: 4429.json - 29 зубов
# Обработано: 4430.json - 30 зубов
# Обработано: 4431.json - 28 зубов
# Обработано: 4432.json - 32 зубов
# Обработано: 4433.json - 32 зубов
# Обработано: 4434.json - 28 зубов
# Обработано: 4435.json - 26 зубов
# Обработано: 4436.json - 30 зубов
# Обработано: 4437.json - 30 зубов
# Обработано: 4438.json - 32 зубов
# Обработано: 4439.json - 26 зубов
# Обработано: 4441.json - 27 зубов
# Обработано: 4442.json - 32 зубов
# Обработано: 4443.json - 32 зубов
# Обработано: 4444.json - 32 зубов
# Обработано: 4446.json - 32 зубов
# Обработано: 4448.json - 32 зубов
# Обработано: 4449.json - 26 зубов
# Обработано: 4450.json - 24 зубов
# Обработано: 4452.json - 31 зубов
# Обработано: 4454.json - 20 зубов
# Обработано: 4457.json - 32 зубов
# Обработано: 4458.json - 32 зубов
# Обработано: 4460.json - 30 зубов
# Обработано: 4462.json - 29 зубов
# Обработано: 4463.json - 31 зубов
# Обработано: 4464.json - 32 зубов
# Обработано: 4465.json - 27 зубов
# Обработано: 4466.json - 31 зубов
# Обработано: 4467.json - 27 зубов
# Обработано: 4468.json - 28 зубов
# Обработано: 4469.json - 26 зубов
# Обработано: 4470.json - 30 зубов
# Обработано: 4471.json - 32 зубов
# Обработано: 4472.json - 28 зубов
# Обработано: 4473.json - 30 зубов
# Обработано: 4474.json - 20 зубов
# Обработано: 4492.json - 28 зубов
# Обработано: 4519.json - 20 зубов
# Обработано: 4520.json - 31 зубов
# Обработано: 4900.json - 32 зубов
# Обработано: 4901.json - 32 зубов
# Обработано: 4902.json - 30 зубов
# Обработано: 4903.json - 33 зубов
# Обработано: 4904.json - 32 зубов
# Обработано: 4905.json - 29 зубов
# Обработано: 4906.json - 10 зубов
# Обработано: 4907.json - 28 зубов
# Обработано: 4908.json - 30 зубов
# Обработано: 4909.json - 29 зубов
# Обработано: 4911.json - 29 зубов
# Обработано: 4912.json - 30 зубов
# Обработано: 4913.json - 24 зубов
# Обработано: 4914.json - 28 зубов
# Обработано: 4916.json - 28 зубов
# Обработано: 4917.json - 31 зубов
# Обработано: 4919.json - 27 зубов
# Обработано: 4920.json - 27 зубов
# Обработано: 4921.json - 30 зубов
# Обработано: 4922.json - 22 зубов
# Обработано: 4923.json - 31 зубов
# Обработано: 4924.json - 30 зубов
# Обработано: 4925.json - 28 зубов
# Обработано: 4926.json - 27 зубов
# Обработано: 4930.json - 13 зубов
# Обработано: 4932.json - 29 зубов
# Обработано: 4933.json - 32 зубов
# Обработано: 4934.json - 30 зубов
# Обработано: 4935.json - 21 зубов
# Обработано: 4936.json - 28 зубов
# Обработано: 4937.json - 27 зубов
# Обработано: 4940.json - 25 зубов
# Обработано: 4941.json - 30 зубов
# Обработано: 4942.json - 32 зубов
# Обработано: 4943.json - 31 зубов
# Обработано: 4944.json - 32 зубов
# Обработано: 4945.json - 32 зубов
# Обработано: 4946.json - 29 зубов
# Обработано: 4947.json - 31 зубов
# Обработано: 4948.json - 32 зубов
# Обработано: 4949.json - 25 зубов
# Обработано: 4950.json - 25 зубов
# Обработано: 4951.json - 30 зубов
# Обработано: 4952.json - 27 зубов
# Обработано: 4953.json - 32 зубов
# Обработано: 4954.json - 31 зубов
# Обработано: 4955.json - 32 зубов
# Обработано: 4956.json - 27 зубов
# Обработано: 4957.json - 32 зубов
# Обработано: 4958.json - 32 зубов
# Обработано: 4959.json - 31 зубов
# Обработано: 4960.json - 26 зубов
# Обработано: 4961.json - 32 зубов
# Обработано: 4962.json - 28 зубов
# Обработано: 4963.json - 28 зубов
# Обработано: 4964.json - 31 зубов
# Обработано: 4966.json - 32 зубов
# Обработано: 4967.json - 31 зубов
# Обработано: 4969.json - 29 зубов
# Обработано: 4971.json - 32 зубов
# Обработано: 4973.json - 32 зубов
# Обработано: 4974.json - 32 зубов
# Обработано: 4975.json - 28 зубов
# Обработано: 4976.json - 28 зубов
# Обработано: 4977.json - 32 зубов
# Обработано: 4978.json - 32 зубов
# Обработано: 4979.json - 32 зубов
# Обработано: 4981.json - 25 зубов
# Обработано: 4982.json - 31 зубов
# Обработано: 4984.json - 32 зубов
# Обработано: 4985.json - 32 зубов
# Обработано: 4986.json - 31 зубов
# Обработано: 4987.json - 26 зубов
# Обработано: 4988.json - 27 зубов
# Обработано: 4989.json - 31 зубов
# Обработано: 4990.json - 32 зубов
# Обработано: 4992.json - 26 зубов
# Обработано: 4993.json - 31 зубов
# Обработано: 4994.json - 26 зубов
# Обработано: 4995.json - 29 зубов
# Обработано: 4996.json - 30 зубов
# Обработано: 4997.json - 32 зубов
# Обработано: 4998.json - 32 зубов
# Обработано: 4999.json - 30 зубов
# Обработано: 5000.json - 31 зубов
# Обработано: 5001.json - 25 зубов
# Обработано: 5002.json - 30 зубов
# Обработано: 5004.json - 26 зубов
# Обработано: 5005.json - 31 зубов
# Обработано: 5006.json - 32 зубов
# Обработано: 5007.json - 28 зубов
# Обработано: 5008.json - 32 зубов
# Обработано: 5010.json - 24 зубов
# Обработано: 5011.json - 28 зубов
# Обработано: 5012.json - 29 зубов
# Обработано: 5013.json - 32 зубов
# Обработано: 5014.json - 27 зубов
# Обработано: 5015.json - 31 зубов
# Обработано: 5016.json - 32 зубов
# Обработано: 5017.json - 30 зубов
# Обработано: 5018.json - 32 зубов
# Обработано: 5019.json - 28 зубов
# Обработано: 5021.json - 32 зубов
# Обработано: 5022.json - 23 зубов
# Обработано: 5023.json - 30 зубов
# Обработано: 5025.json - 30 зубов
# Обработано: 5027.json - 27 зубов
# Обработано: 5028.json - 31 зубов
# Обработано: 5029.json - 32 зубов
# Обработано: 5030.json - 32 зубов
# Обработано: 5031.json - 28 зубов
# Обработано: 5032.json - 28 зубов
# Обработано: 5033.json - 28 зубов
# Обработано: 5034.json - 23 зубов
# Обработано: 5035.json - 27 зубов
# Обработано: 5036.json - 32 зубов
# Обработано: 5037.json - 32 зубов
# Обработано: 5039.json - 32 зубов
# Обработано: 5040.json - 29 зубов
# Обработано: 5041.json - 32 зубов
# Обработано: 5042.json - 28 зубов
# Обработано: 5044.json - 32 зубов
# Обработано: 5045.json - 28 зубов
# Обработано: 5046.json - 28 зубов
# Обработано: 5047.json - 31 зубов
# Обработано: 5048.json - 30 зубов
# Обработано: 5049.json - 21 зубов
# Обработано: 5051.json - 30 зубов
# Обработано: 5052.json - 27 зубов
# Обработано: 5053.json - 31 зубов
# Обработано: 5054.json - 31 зубов
# Обработано: 5055.json - 30 зубов
# Обработано: 5056.json - 23 зубов
# Обработано: 5058.json - 31 зубов
# Обработано: 5059.json - 31 зубов
# Обработано: 5060.json - 32 зубов
# Обработано: 5061.json - 24 зубов
# Обработано: 5062.json - 23 зубов
# Обработано: 5064.json - 32 зубов
# Обработано: 5065.json - 32 зубов
# Обработано: 5066.json - 32 зубов
# Обработано: 5067.json - 29 зубов
# Обработано: 5068.json - 28 зубов
# Обработано: 5069.json - 28 зубов
# Обработано: 5070.json - 31 зубов
# Обработано: 5072.json - 31 зубов
# Обработано: 5074.json - 31 зубов
# Обработано: 5075.json - 27 зубов
# Обработано: 5076.json - 11 зубов
# Обработано: 5077.json - 23 зубов
# Обработано: 5079.json - 32 зубов
# Обработано: 5081.json - 14 зубов
# Обработано: 5082.json - 26 зубов
# Обработано: 5084.json - 21 зубов
# Обработано: 5085.json - 32 зубов
# Обработано: 5086.json - 32 зубов
# Обработано: 5087.json - 29 зубов
# Обработано: 5088.json - 23 зубов
# Обработано: 5089.json - 31 зубов
# Обработано: 5090.json - 27 зубов
# Обработано: 5091.json - 26 зубов
# Обработано: 5092.json - 31 зубов
# Обработано: 5093.json - 31 зубов
# Обработано: 5095.json - 31 зубов
# Обработано: 5096.json - 28 зубов
# Обработано: 5097.json - 29 зубов
# Обработано: 5099.json - 31 зубов
# Обработано: 5100.json - 30 зубов
# Обработано: 5101.json - 26 зубов
# Обработано: 5102.json - 30 зубов
# Обработано: 5103.json - 28 зубов
# Обработано: 5104.json - 31 зубов
# Обработано: 5105.json - 29 зубов
# Обработано: 5106.json - 25 зубов
# Обработано: 5107.json - 31 зубов
# Обработано: 5108.json - 31 зубов
# Обработано: 5109.json - 32 зубов
# Обработано: 5110.json - 32 зубов
# Обработано: 5111.json - 14 зубов
# Обработано: 5112.json - 14 зубов
# Обработано: 5113.json - 30 зубов
# Обработано: 5114.json - 23 зубов
# Обработано: 5116.json - 29 зубов
# Обработано: 5117.json - 30 зубов
# Обработано: 5118.json - 32 зубов
# Обработано: 5119.json - 31 зубов
# Обработано: 5120.json - 32 зубов
# Обработано: 5121.json - 31 зубов
# Обработано: 5122.json - 19 зубов
# Обработано: 5123.json - 29 зубов
# Обработано: 5124.json - 24 зубов
# Обработано: 5125.json - 23 зубов
# Обработано: 5126.json - 31 зубов
# Обработано: 5127.json - 31 зубов
# Обработано: 5128.json - 29 зубов
# Обработано: 5129.json - 32 зубов
# Обработано: 5132.json - 30 зубов
# Обработано: 5133.json - 29 зубов
# Обработано: 5134.json - 30 зубов
# Обработано: 5135.json - 28 зубов
# Обработано: 5136.json - 31 зубов
# Обработано: 5137.json - 30 зубов
# Обработано: 5138.json - 32 зубов
# Обработано: 5139.json - 32 зубов
# Обработано: 5140.json - 30 зубов
# Обработано: 5141.json - 32 зубов
# Обработано: 5142.json - 26 зубов
# Обработано: 5143.json - 28 зубов
# Обработано: 5144.json - 32 зубов
# Обработано: 5146.json - 30 зубов
# Обработано: 5147.json - 31 зубов
# Обработано: 5148.json - 27 зубов
# Обработано: 5149.json - 30 зубов
# Обработано: 5151.json - 30 зубов
# Обработано: 5152.json - 28 зубов
# Обработано: 5154.json - 27 зубов
# Обработано: 5155.json - 32 зубов
# Обработано: 5156.json - 30 зубов
# Обработано: 5157.json - 32 зубов
# Обработано: 5158.json - 30 зубов
# Обработано: 5159.json - 23 зубов
# Обработано: 5161.json - 32 зубов
# Обработано: 5162.json - 32 зубов
# Обработано: 5163.json - 13 зубов
# Обработано: 5165.json - 30 зубов
# Обработано: 5166.json - 19 зубов
# Обработано: 5168.json - 11 зубов
# Обработано: 5169.json - 32 зубов
# Обработано: 5170.json - 29 зубов
# Обработано: 5171.json - 29 зубов
# Обработано: 5172.json - 25 зубов
# Обработано: 5173.json - 27 зубов
# Обработано: 5175.json - 29 зубов
# Обработано: 5176.json - 32 зубов
# Обработано: 5178.json - 28 зубов
# Обработано: 5179.json - 30 зубов
# Обработано: 5180.json - 27 зубов
# Обработано: 5181.json - 32 зубов
# Обработано: 5182.json - 31 зубов
# Обработано: 5183.json - 32 зубов
# Обработано: 5184.json - 32 зубов
# Обработано: 5185.json - 32 зубов
# Обработано: 5186.json - 28 зубов
# Обработано: 5187.json - 24 зубов
# Обработано: 5189.json - 29 зубов
# Обработано: 5190.json - 30 зубов
# Обработано: 5191.json - 31 зубов
# Обработано: 5192.json - 29 зубов
# Обработано: 5193.json - 22 зубов
# Обработано: 5194.json - 29 зубов
# Обработано: 5195.json - 32 зубов
# Обработано: 5196.json - 32 зубов
# Обработано: 5198.json - 32 зубов
# Обработано: 5199.json - 29 зубов
# Обработано: 5200.json - 31 зубов
# Обработано: 5201.json - 30 зубов
# Обработано: 5202.json - 25 зубов
# Обработано: 5203.json - 32 зубов
# Обработано: 5204.json - 32 зубов
# Обработано: 5205.json - 31 зубов
# Обработано: 5207.json - 31 зубов
# Обработано: 5208.json - 30 зубов
# Обработано: 5210.json - 30 зубов
# Обработано: 5211.json - 31 зубов
# Обработано: 5213.json - 29 зубов
# Обработано: 5214.json - 28 зубов
# Обработано: 5215.json - 22 зубов
# Обработано: 5216.json - 27 зубов
# Обработано: 5217.json - 31 зубов
# Обработано: 5218.json - 28 зубов
# Обработано: 5219.json - 29 зубов
# Обработано: 5222.json - 30 зубов
# Обработано: 5223.json - 28 зубов
# Обработано: 5224.json - 26 зубов
# Обработано: 5225.json - 32 зубов
# Обработано: 5226.json - 32 зубов
# Обработано: 5227.json - 31 зубов
# Обработано: 5228.json - 32 зубов
# Обработано: 5229.json - 25 зубов
# Обработано: 5231.json - 30 зубов
# Обработано: 5232.json - 27 зубов
# Обработано: 5234.json - 32 зубов
# Обработано: 5235.json - 29 зубов
# Обработано: 5236.json - 30 зубов
# Обработано: 5237.json - 32 зубов
# Обработано: 5238.json - 30 зубов
# Обработано: 5239.json - 30 зубов
# Обработано: 5240.json - 28 зубов
# Обработано: 5241.json - 25 зубов
# Обработано: 5242.json - 32 зубов
# Обработано: 5243.json - 32 зубов
# Обработано: 5244.json - 31 зубов
# Обработано: 5245.json - 28 зубов
# Обработано: 5246.json - 31 зубов
# Обработано: 5248.json - 29 зубов
# Обработано: 5249.json - 29 зубов
# Обработано: 5250.json - 27 зубов
# Обработано: 5251.json - 29 зубов
# Обработано: 5252.json - 30 зубов
# Обработано: 5253.json - 33 зубов
# Обработано: 5254.json - 32 зубов
# Обработано: 5400.json - 26 зубов
# Обработано: 5401.json - 30 зубов
# Обработано: 5402.json - 30 зубов
# Обработано: 5404.json - 27 зубов
# Обработано: 5405.json - 29 зубов
# Обработано: 5406.json - 32 зубов
# Обработано: 5408.json - 29 зубов
# Обработано: 5409.json - 31 зубов
# Обработано: 5411.json - 33 зубов
# Обработано: 5412.json - 27 зубов
# Обработано: 5413.json - 30 зубов
# Обработано: 5415.json - 28 зубов
# Обработано: 5416.json - 31 зубов
# Обработано: 5417.json - 26 зубов
# Обработано: 5418.json - 32 зубов
# Обработано: 5419.json - 28 зубов
# Обработано: 5420.json - 32 зубов
# Обработано: 5423.json - 29 зубов
# Обработано: 5424.json - 32 зубов
# Обработано: 5425.json - 30 зубов
# Обработано: 5426.json - 32 зубов
# Обработано: 5428.json - 24 зубов
# Обработано: 5429.json - 27 зубов
# Обработано: 5430.json - 32 зубов
# Обработано: 5431.json - 30 зубов
# Обработано: 5432.json - 32 зубов
# Обработано: 5434.json - 32 зубов
# Обработано: 5435.json - 28 зубов
# Обработано: 5436.json - 32 зубов
# Обработано: 5438.json - 30 зубов
# Обработано: 5439.json - 28 зубов
# Обработано: 5440.json - 20 зубов
# Обработано: 5441.json - 29 зубов
# Обработано: 5442.json - 31 зубов
# Обработано: 5443.json - 29 зубов
# Обработано: 5444.json - 31 зубов
# Обработано: 5446.json - 31 зубов
# Обработано: 5447.json - 32 зубов
# Обработано: 5448.json - 32 зубов
# Обработано: 5449.json - 30 зубов
# Обработано: 5450.json - 29 зубов
# Обработано: 5451.json - 31 зубов
# Обработано: 5452.json - 32 зубов
# Обработано: 5453.json - 32 зубов
# Обработано: 5454.json - 32 зубов
# Обработано: 5456.json - 30 зубов
# Обработано: 5458.json - 22 зубов
# Обработано: 5459.json - 31 зубов
# Обработано: 5460.json - 28 зубов
# Обработано: 5461.json - 26 зубов
# Обработано: 5462.json - 29 зубов
# Обработано: 5464.json - 28 зубов
# Обработано: 5465.json - 28 зубов
# Обработано: 5466.json - 30 зубов
# Обработано: 5467.json - 30 зубов
# Обработано: 5468.json - 31 зубов
# Обработано: 5469.json - 31 зубов
# Обработано: 5471.json - 32 зубов
# Обработано: 5472.json - 29 зубов
# Обработано: 5473.json - 32 зубов
# Обработано: 5475.json - 30 зубов
# Обработано: 5477.json - 29 зубов
# Обработано: 5478.json - 27 зубов
# Обработано: 5479.json - 31 зубов
# Обработано: 5481.json - 27 зубов
# Обработано: 5482.json - 32 зубов
# Обработано: 5483.json - 23 зубов
# Обработано: 5484.json - 31 зубов
# Обработано: 5485.json - 28 зубов
# Обработано: 5489.json - 30 зубов
# Обработано: 5491.json - 27 зубов
# Обработано: 5492.json - 31 зубов
# Обработано: 5493.json - 28 зубов
# Обработано: 5494.json - 31 зубов
# Обработано: 5495.json - 27 зубов
# Обработано: 5496.json - 28 зубов
# Обработано: 5498.json - 30 зубов
# Обработано: 5502.json - 21 зубов
# Обработано: 5503.json - 32 зубов
# Обработано: 5504.json - 32 зубов
# Обработано: 5505.json - 28 зубов
# Обработано: 5506.json - 32 зубов
# Обработано: 5507.json - 32 зубов
# Обработано: 5508.json - 32 зубов
# Обработано: 5509.json - 29 зубов
# Обработано: 5510.json - 28 зубов
# Обработано: 5511.json - 25 зубов
# Обработано: 5513.json - 26 зубов
# Обработано: 5514.json - 31 зубов
# Обработано: 5515.json - 28 зубов
# Обработано: 5516.json - 28 зубов
# Обработано: 5517.json - 26 зубов
# Обработано: 5518.json - 29 зубов
# Обработано: 5520.json - 28 зубов
# Обработано: 5521.json - 30 зубов
# Обработано: 5522.json - 30 зубов
# Обработано: 5523.json - 29 зубов
# Обработано: 5524.json - 23 зубов
# Обработано: 5526.json - 32 зубов
# Обработано: 5527.json - 23 зубов
# Обработано: 5528.json - 31 зубов
# Обработано: 5529.json - 18 зубов
# Обработано: 5530.json - 24 зубов
# Обработано: 5531.json - 26 зубов
# Обработано: 5532.json - 30 зубов
# Обработано: 5534.json - 27 зубов
# Обработано: 5536.json - 30 зубов
# Обработано: 5538.json - 26 зубов
# Обработано: 5539.json - 30 зубов
# Обработано: 5541.json - 30 зубов
# Обработано: 5543.json - 31 зубов
# Обработано: 5544.json - 29 зубов
# Обработано: 5545.json - 29 зубов
# Обработано: 5546.json - 28 зубов
# Обработано: 5547.json - 31 зубов
# Обработано: 5548.json - 30 зубов
# Обработано: 5549.json - 28 зубов
# Обработано: 5550.json - 30 зубов
# Обработано: 5551.json - 32 зубов
# Обработано: 5552.json - 30 зубов
# Обработано: 5553.json - 28 зубов
# Обработано: 5554.json - 28 зубов
# Обработано: 5556.json - 32 зубов
# Обработано: 5557.json - 28 зубов
# Обработано: 5558.json - 29 зубов
# Обработано: 5559.json - 32 зубов
# Обработано: 5560.json - 30 зубов
# Обработано: 5561.json - 32 зубов
# Обработано: 5562.json - 32 зубов
# Обработано: 5563.json - 25 зубов
# Обработано: 5564.json - 27 зубов
# Обработано: 5565.json - 32 зубов
# Обработано: 5566.json - 28 зубов
# Обработано: 5567.json - 28 зубов
# Обработано: 5568.json - 28 зубов
# Обработано: 5569.json - 32 зубов
# Обработано: 5570.json - 32 зубов
# Обработано: 5571.json - 30 зубов
# Обработано: 5572.json - 31 зубов
# Обработано: 5573.json - 26 зубов
# Обработано: 5574.json - 29 зубов
# Обработано: 5575.json - 25 зубов
# Обработано: 5577.json - 30 зубов
# Обработано: 5578.json - 29 зубов
# Обработано: 5582.json - 28 зубов
# Обработано: 5583.json - 26 зубов
# Обработано: 5585.json - 26 зубов
# Обработано: 5586.json - 26 зубов
# Обработано: 5588.json - 32 зубов
# Обработано: 5589.json - 30 зубов
# Обработано: 5591.json - 27 зубов
# Обработано: 5594.json - 32 зубов
# Обработано: 5596.json - 26 зубов
# Обработано: 5598.json - 31 зубов
# Обработано: 5599.json - 29 зубов
# Обработано: 5600.json - 24 зубов
# Обработано: 5601.json - 29 зубов
# Обработано: 5602.json - 31 зубов
# Обработано: 5603.json - 28 зубов
# Обработано: 5604.json - 29 зубов
# Обработано: 5605.json - 31 зубов
# Обработано: 5606.json - 28 зубов
# Обработано: 5607.json - 32 зубов
# Обработано: 5608.json - 28 зубов
# Обработано: 5610.json - 32 зубов
# Обработано: 5611.json - 31 зубов
# Обработано: 5612.json - 32 зубов
# Обработано: 5613.json - 26 зубов
# Обработано: 5614.json - 27 зубов
# Обработано: 5615.json - 27 зубов
# Обработано: 5616.json - 28 зубов
# Обработано: 5617.json - 26 зубов
# Обработано: 5618.json - 29 зубов
# Обработано: 5619.json - 30 зубов
# Обработано: 5620.json - 30 зубов
# Обработано: 5621.json - 32 зубов
# Обработано: 5622.json - 27 зубов
# Обработано: 5623.json - 28 зубов
# Обработано: 5624.json - 31 зубов
# Обработано: 5627.json - 30 зубов
# Обработано: 5628.json - 27 зубов
# Обработано: 5629.json - 28 зубов
# Обработано: 5630.json - 24 зубов
# Обработано: 5631.json - 31 зубов
# Обработано: 5632.json - 30 зубов
# Обработано: 5633.json - 31 зубов
# Обработано: 5634.json - 31 зубов
# Обработано: 5635.json - 32 зубов
# Обработано: 5636.json - 32 зубов
# Обработано: 5637.json - 30 зубов
# Обработано: 5638.json - 30 зубов
# Обработано: 5639.json - 32 зубов
# Обработано: 5640.json - 26 зубов
# Обработано: 5641.json - 29 зубов
# Обработано: 5643.json - 25 зубов
# Обработано: 5644.json - 32 зубов
# Обработано: 5645.json - 31 зубов
# Обработано: 5646.json - 32 зубов
# Обработано: 5647.json - 29 зубов
# Обработано: 5648.json - 28 зубов
# Обработано: 5649.json - 25 зубов
# Обработано: 5650.json - 32 зубов
# Обработано: 5651.json - 31 зубов
# Обработано: 5652.json - 29 зубов
# Обработано: 5653.json - 31 зубов
# Обработано: 5654.json - 28 зубов
# Обработано: 5655.json - 29 зубов
# Обработано: 5656.json - 27 зубов
# Обработано: 5657.json - 24 зубов
# Обработано: 5658.json - 24 зубов
# Обработано: 5659.json - 29 зубов
# Обработано: 5660.json - 31 зубов
# Обработано: 5661.json - 32 зубов
# Обработано: 5662.json - 27 зубов
# Обработано: 5663.json - 32 зубов
# Обработано: 5664.json - 31 зубов
# Обработано: 5665.json - 29 зубов
# Обработано: 5666.json - 27 зубов
# Обработано: 5667.json - 25 зубов
# Обработано: 5668.json - 24 зубов
# Обработано: 5670.json - 31 зубов
# Обработано: 5671.json - 28 зубов
# Обработано: 5674.json - 32 зубов
# Обработано: 5675.json - 29 зубов
# Обработано: 5676.json - 28 зубов
# Обработано: 5677.json - 30 зубов
# Обработано: 5678.json - 30 зубов
# Обработано: 5679.json - 30 зубов
# Обработано: 5680.json - 32 зубов
# Обработано: 5681.json - 33 зубов
# Обработано: 5682.json - 30 зубов
# Обработано: 5683.json - 27 зубов
# Обработано: 5684.json - 29 зубов
# Обработано: 5685.json - 31 зубов
# Обработано: 5687.json - 31 зубов
# Обработано: 5689.json - 29 зубов
# Обработано: 5690.json - 28 зубов
# Обработано: 5691.json - 31 зубов
# Обработано: 5692.json - 33 зубов
# Обработано: 5693.json - 30 зубов
# Обработано: 5694.json - 28 зубов
# Обработано: 5695.json - 11 зубов
# Обработано: 5696.json - 32 зубов
# Обработано: 5697.json - 28 зубов
# Обработано: 8000.json - 16 зубов
# Обработано: 8001.json - 23 зубов
# Обработано: 8002.json - 29 зубов
# Обработано: 8003.json - 14 зубов
# Обработано: 8004.json - 24 зубов
# Обработано: 8005.json - 14 зубов
# Обработано: 8006.json - 24 зубов
# Обработано: 8007.json - 14 зубов
# Обработано: 8008.json - 8 зубов
# Обработано: 8009.json - 27 зубов
# Обработано: 8010.json - 28 зубов
# Обработано: 8011.json - 30 зубов
# Обработано: 8012.json - 4 зубов
# Обработано: 8013.json - 31 зубов
# Обработано: 8014.json - 30 зубов
# Обработано: 8015.json - 32 зубов
# Обработано: 8016.json - 26 зубов
# Обработано: 8017.json - 28 зубов
# Обработано: 8018.json - 26 зубов
# Обработано: 8019.json - 31 зубов
# Обработано: 8020.json - 29 зубов
# Обработано: 8021.json - 27 зубов
# Обработано: 8022.json - 22 зубов
# Обработано: 8023.json - 20 зубов
# Обработано: 8024.json - 24 зубов
# Обработано: 8025.json - 28 зубов
# Обработано: 8026.json - 31 зубов
# Обработано: 8027.json - 32 зубов
# Обработано: 8028.json - 20 зубов
# Обработано: 8029.json - 29 зубов
# Обработано: 8030.json - 30 зубов
# Обработано: 8031.json - 28 зубов
# Обработано: 8032.json - 28 зубов
# Обработано: 8033.json - 29 зубов
# Обработано: 8034.json - 15 зубов
# Обработано: 8035.json - 16 зубов
# Обработано: 8036.json - 16 зубов
# Обработано: 8037.json - 24 зубов
# Обработано: 8038.json - 31 зубов
# Обработано: 8039.json - 33 зубов
# Обработано: 8040.json - 27 зубов
# Обработано: 8041.json - 30 зубов
# Обработано: 8042.json - 18 зубов
# Обработано: 8043.json - 18 зубов
# Обработано: 8044.json - 26 зубов
# Обработано: 8045.json - 28 зубов
# Обработано: 8046.json - 27 зубов
# Обработано: 8047.json - 19 зубов
# Обработано: 8048.json - 29 зубов
# Обработано: 8049.json - 28 зубов
# Обработано: 8050.json - 20 зубов
# Обработано: 8051.json - 25 зубов
# Обработано: 8052.json - 32 зубов
# Обработано: 8053.json - 28 зубов
# Обработано: 8054.json - 28 зубов
# Обработано: 8055.json - 28 зубов
# Обработано: 8056.json - 6 зубов
# Обработано: 8057.json - 29 зубов
# Обработано: 8058.json - 31 зубов
# Обработано: 8059.json - 24 зубов
# Обработано: 8060.json - 30 зубов
# Обработано: 8061.json - 26 зубов
# Обработано: 8062.json - 9 зубов
# Обработано: 8063.json - 26 зубов
# Обработано: 8064.json - 13 зубов
# Обработано: 8065.json - 13 зубов
# Обработано: 8066.json - 31 зубов
# Обработано: 8067.json - 29 зубов
# Обработано: 8068.json - 23 зубов
# Обработано: 8069.json - 26 зубов
# Обработано: 8070.json - 28 зубов
# Обработано: 8071.json - 31 зубов
# Обработано: 8072.json - 32 зубов
# Обработано: 8073.json - 29 зубов
# Обработано: 8074.json - 26 зубов
# Обработано: 8075.json - 28 зубов
# Обработано: 8076.json - 32 зубов
# Обработано: 8078.json - 28 зубов
# Обработано: 8079.json - 28 зубов
# Обработано: 8080.json - 5 зубов
# Обработано: 8081.json - 31 зубов
# Обработано: 8082.json - 16 зубов
# Обработано: 8083.json - 32 зубов
# Обработано: 8084.json - 26 зубов
# Обработано: 8085.json - 29 зубов
# Обработано: 8086.json - 11 зубов
# Обработано: 8087.json - 28 зубов
# Обработано: 8088.json - 22 зубов
# Обработано: 8089.json - 31 зубов
# Обработано: 8090.json - 25 зубов
# Обработано: 8091.json - 32 зубов
# Обработано: 8092.json - 31 зубов
# Обработано: 8093.json - 29 зубов
# Обработано: 8094.json - 24 зубов
# Обработано: 8095.json - 24 зубов
# Обработано: 8096.json - 21 зубов
# Обработано: 8097.json - 30 зубов
# Обработано: 8098.json - 33 зубов
# Обработано: 8099.json - 32 зубов
# Обработано: 8100.json - 30 зубов
# Обработано: 8101.json - 24 зубов
# Обработано: 8102.json - 27 зубов
# Обработано: 8103.json - 12 зубов
# Обработано: 8104.json - 30 зубов
# Обработано: 8105.json - 18 зубов
# Обработано: 8106.json - 32 зубов
# Обработано: 8107.json - 31 зубов
# Обработано: 8108.json - 32 зубов
# Обработано: 8109.json - 23 зубов
# Обработано: 8110.json - 20 зубов
# Обработано: 8111.json - 21 зубов
# Обработано: 8112.json - 30 зубов
# Обработано: 8113.json - 27 зубов
# Обработано: 8114.json - 31 зубов
# Обработано: 8115.json - 26 зубов
# Обработано: 8116.json - 30 зубов
# Обработано: 8117.json - 29 зубов
# Обработано: 8118.json - 32 зубов
# Обработано: 8119.json - 24 зубов
# Обработано: 8120.json - 21 зубов
# Обработано: 8121.json - 25 зубов
# Обработано: 8122.json - 29 зубов
# Обработано: 8123.json - 32 зубов
# Обработано: 8124.json - 19 зубов
# Обработано: 8125.json - 16 зубов
# Обработано: 8126.json - 30 зубов
# Обработано: 8127.json - 30 зубов
# Обработано: 8128.json - 27 зубов
# Обработано: 8129.json - 15 зубов
# Обработано: 8130.json - 29 зубов
# Обработано: 8131.json - 27 зубов
# Обработано: 8132.json - 30 зубов
# Обработано: 8133.json - 30 зубов
# Обработано: 8134.json - 29 зубов
# Обработано: 8135.json - 28 зубов
# Обработано: 8136.json - 26 зубов
# Обработано: 8137.json - 28 зубов
# Обработано: 8138.json - 22 зубов
# Обработано: 8139.json - 25 зубов
# Обработано: 8140.json - 30 зубов
# Обработано: 8141.json - 32 зубов
# Обработано: 8142.json - 21 зубов
# Обработано: 8144.json - 28 зубов
# Обработано: 8145.json - 32 зубов
# Обработано: 8146.json - 23 зубов
# Обработано: 8148.json - 32 зубов
# Обработано: 8149.json - 31 зубов
# Обработано: 8150.json - 28 зубов
# Обработано: 8151.json - 30 зубов
# Обработано: 8152.json - 28 зубов
# Обработано: 8153.json - 29 зубов
# Обработано: 8154.json - 29 зубов
# Обработано: 8155.json - 14 зубов
# Обработано: 8157.json - 30 зубов
# Обработано: 8158.json - 32 зубов
# Обработано: 8159.json - 26 зубов
# Обработано: 8160.json - 27 зубов
# Обработано: 8161.json - 32 зубов
# Обработано: 8162.json - 29 зубов
# Обработано: 8163.json - 28 зубов
# Обработано: 8164.json - 24 зубов
# Обработано: 8166.json - 27 зубов
# Обработано: 8167.json - 31 зубов
# Обработано: 8168.json - 27 зубов
# Обработано: 8169.json - 30 зубов
# Обработано: 8170.json - 20 зубов
# Обработано: 8171.json - 27 зубов
# Обработано: 8172.json - 21 зубов
# Обработано: 8173.json - 25 зубов
# Обработано: 8174.json - 31 зубов
# Обработано: 8175.json - 20 зубов
# Обработано: 8176.json - 25 зубов
# Обработано: 8177.json - 29 зубов
# Обработано: 8178.json - 29 зубов
# Обработано: 8179.json - 28 зубов
# Обработано: 8180.json - 9 зубов
# Обработано: 8181.json - 30 зубов
# Обработано: 8182.json - 32 зубов
# Обработано: 8183.json - 27 зубов
# Обработано: 8184.json - 30 зубов
# Обработано: 8185.json - 30 зубов
# Обработано: 8186.json - 21 зубов
# Обработано: 8187.json - 24 зубов
# Обработано: 8188.json - 26 зубов
# Обработано: 8189.json - 32 зубов
# Обработано: 8190.json - 11 зубов
# Обработано: 8191.json - 32 зубов
# Обработано: 8192.json - 28 зубов
# Обработано: 8193.json - 31 зубов
# Обработано: 8194.json - 26 зубов
# Обработано: 8195.json - 30 зубов
# Обработано: 8196.json - 31 зубов
# Обработано: 8197.json - 27 зубов
# Обработано: 8198.json - 31 зубов
# Обработано: 8199.json - 30 зубов
# Обработано: 8200.json - 32 зубов
# Обработано: 8201.json - 32 зубов
# Обработано: 8202.json - 24 зубов
# Обработано: 8203.json - 36 зубов
# Обработано: 8204.json - 26 зубов
# Обработано: 8205.json - 24 зубов
# Обработано: 8206.json - 31 зубов
# Обработано: 8207.json - 23 зубов
# Обработано: 8208.json - 31 зубов
# Обработано: 8209.json - 23 зубов
# Обработано: 8210.json - 22 зубов
# Обработано: 8211.json - 29 зубов
# Обработано: 8212.json - 14 зубов
# Обработано: 8213.json - 19 зубов
# Обработано: 8214.json - 18 зубов
# Обработано: 8215.json - 30 зубов
# Обработано: 8216.json - 32 зубов
# Обработано: 8217.json - 30 зубов
# Обработано: cw1000.json - 32 зубов
# Обработано: cw1001.json - 28 зубов
# Обработано: cw1002.json - 26 зубов
# Обработано: cw1003.json - 32 зубов
# Обработано: cw1004.json - 32 зубов
# Обработано: cw1005.json - 22 зубов
# Обработано: cw1006.json - 28 зубов
# Обработано: cw1007.json - 32 зубов
# Обработано: cw1008.json - 32 зубов
# Обработано: cw1009.json - 31 зубов
# Обработано: cw1010.json - 32 зубов
# Обработано: cw1011.json - 30 зубов
# Обработано: cw1012.json - 26 зубов
# Обработано: cw1013.json - 30 зубов
# Обработано: cw1014.json - 27 зубов
# Обработано: cw1015.json - 32 зубов
# Обработано: cw1016.json - 32 зубов
# Обработано: cw1017.json - 27 зубов
# Обработано: cw1018.json - 32 зубов
# Обработано: cw1019.json - 31 зубов
# Обработано: cw1020.json - 32 зубов
# Обработано: cw1021.json - 31 зубов
# Обработано: cw1022.json - 32 зубов
# Обработано: cw1023.json - 32 зубов
# Обработано: cw1024.json - 32 зубов
# Обработано: cw1025.json - 28 зубов
# Обработано: cw1026.json - 32 зубов
# Обработано: cw1027.json - 29 зубов
# Обработано: cw1028.json - 32 зубов
# Обработано: cw1029.json - 30 зубов
# Обработано: cw1030.json - 30 зубов
# Обработано: cw1031.json - 30 зубов
# Обработано: cw1032.json - 28 зубов
# Обработано: cw1033.json - 31 зубов
# Обработано: cw1034.json - 27 зубов
# Обработано: cw1035.json - 27 зубов
# Обработано: cw1036.json - 29 зубов
# Обработано: cw1037.json - 12 зубов
# Обработано: cw1038.json - 32 зубов
# Обработано: cw1039.json - 31 зубов
# Обработано: cw1040.json - 30 зубов
# Обработано: cw1041.json - 19 зубов
# Обработано: cw1042.json - 32 зубов
# Обработано: cw1043.json - 29 зубов
# Обработано: cw1044.json - 31 зубов
# Обработано: cw1045.json - 32 зубов
# Обработано: cw1046.json - 32 зубов
# Обработано: cw1047.json - 32 зубов
# Обработано: cw1048.json - 29 зубов
# Обработано: cw1049.json - 32 зубов
# Обработано: cw1050.json - 27 зубов
# Обработано: cw1051.json - 30 зубов
# Обработано: cw1052.json - 30 зубов
# Обработано: cw1053.json - 30 зубов
# Обработано: cw1054.json - 32 зубов
# Обработано: cw1055.json - 27 зубов
# Обработано: cw1056.json - 31 зубов
# Обработано: cw1057.json - 28 зубов
# Обработано: cw1058.json - 32 зубов
# Обработано: cw1059.json - 32 зубов
# Обработано: cw1060.json - 24 зубов
# Обработано: cw1061.json - 26 зубов
# Обработано: cw1062.json - 32 зубов
# Обработано: cw1063.json - 32 зубов
# Обработано: cw1064.json - 29 зубов
# Обработано: cw1065.json - 29 зубов
# Обработано: cw1066.json - 30 зубов
# Обработано: cw1067.json - 32 зубов
# Обработано: cw1068.json - 32 зубов
# Обработано: cw1069.json - 31 зубов
# Обработано: cw1070.json - 30 зубов
# Обработано: cw1071.json - 30 зубов
# Обработано: cw1072.json - 30 зубов
# Обработано: cw1073.json - 19 зубов
# Обработано: cw1074.json - 32 зубов
# Обработано: cw1075.json - 31 зубов
# Обработано: cw1076.json - 32 зубов
# Обработано: cw1077.json - 32 зубов
# Обработано: cw1078.json - 32 зубов
# Обработано: cw1079.json - 31 зубов
# Обработано: cw1080.json - 31 зубов
# Обработано: cw1081.json - 30 зубов
# Обработано: cw1082.json - 29 зубов
# Обработано: cw1084.json - 32 зубов
# Обработано: cw1085.json - 29 зубов
# Обработано: cw1086.json - 27 зубов
# Обработано: cw1087.json - 31 зубов
# Обработано: cw1088.json - 30 зубов
# Обработано: cw1089.json - 28 зубов
# Обработано: cw1090.json - 28 зубов
# Обработано: cw1091.json - 28 зубов
# Обработано: cw1092.json - 32 зубов
# Обработано: cw1093.json - 29 зубов
# Обработано: cw1094.json - 32 зубов
# Обработано: cw1095.json - 28 зубов
# Обработано: cw1096.json - 31 зубов
# Обработано: cw1097.json - 27 зубов
# Обработано: cw1098.json - 32 зубов
# Обработано: cw1099.json - 28 зубов
# Обработано: cw1100.json - 24 зубов
# Обработано: cw1101.json - 30 зубов
# Обработано: cw1102.json - 32 зубов
# Обработано: cw1103.json - 29 зубов
# Обработано: cw1104.json - 32 зубов
# Обработано: cw1105.json - 31 зубов
# Обработано: cw1106.json - 26 зубов
# Обработано: cw1107.json - 30 зубов
# Обработано: cw1109.json - 31 зубов
# Обработано: cw1110.json - 13 зубов
# Обработано: cw1111.json - 13 зубов
# Обработано: cw1112.json - 32 зубов
# Обработано: cw1113.json - 31 зубов
# Обработано: cw1114.json - 31 зубов
# Обработано: cw1115.json - 31 зубов
# Обработано: cw1116.json - 29 зубов
# Обработано: cw1117.json - 30 зубов
# Обработано: cw1118.json - 32 зубов
# Обработано: cw1119.json - 32 зубов
# Обработано: cw1120.json - 31 зубов
# Обработано: cw1121.json - 32 зубов
# Обработано: cw1122.json - 28 зубов
# Обработано: cw1124.json - 28 зубов
# Обработано: cw1126.json - 30 зубов
# Обработано: cw1127.json - 31 зубов
# Обработано: cw1128.json - 32 зубов
# Обработано: cw1129.json - 32 зубов
# Обработано: cw1130.json - 33 зубов
# Обработано: cw1131.json - 32 зубов
# Обработано: cw1132.json - 31 зубов
# Обработано: cw1133.json - 32 зубов
# Обработано: cw1134.json - 32 зубов
# Обработано: cw1135.json - 29 зубов
# Обработано: cw1136.json - 29 зубов
# Обработано: cw1137.json - 27 зубов
# Обработано: cw1138.json - 31 зубов
# Обработано: cw1139.json - 28 зубов
# Обработано: cw1140.json - 32 зубов
# Обработано: cw1141.json - 27 зубов
# Обработано: cw1142.json - 31 зубов
# Обработано: cw1143.json - 32 зубов
# Обработано: cw1144.json - 32 зубов
# Обработано: cw1145.json - 31 зубов
# Обработано: cw1147.json - 24 зубов
# Обработано: cw1148.json - 24 зубов
# Обработано: cw1149.json - 31 зубов
# Обработано: cw1150.json - 32 зубов
# Обработано: cw1151.json - 32 зубов
# Обработано: cw1152.json - 32 зубов
# Обработано: cw1153.json - 29 зубов
# Обработано: cw1154.json - 32 зубов
# ...
# Обработано: cw1373.json - 32 зубов
# Обработано: cw1374.json - 32 зубов
# Обработано: cw1375.json - 32 зубов
# Обработано: cw1376.json - 32 зубов
# Обработано: cw1377.json - 32 зубов
# Обработано: cw1378.json - 31 зубов
# Обработано: cw1379.json - 32 зубов
# Обработано: cw1380.json - 30 зубов
# Обработано: cw1381.json - 32 зубов
# Обработано: cw1382.json - 30 зубов
# Обработано: cw1383.json - 21 зубов
# Обработано: cw1384.json - 31 зубов
# Обработано: cw1385.json - 32 зубов
# Обработано: cw1386.json - 32 зубов
# Обработано: cw1387.json - 32 зубов
# Обработано: cw1388.json - 32 зубов
# Обработано: cw1389.json - 30 зубов
# Обработано: cw1390.json - 26 зубов
# Обработано: cw1391.json - 31 зубов
# Обработано: cw1392.json - 32 зубов
# Обработано: cw1393.json - 28 зубов
# Обработано: cw1394.json - 26 зубов
# Обработано: cw1395.json - 31 зубов
# Обработано: cw1396.json - 32 зубов
# Обработано: cw1397.json - 32 зубов
# Обработано: cw1398.json - 32 зубов
# Обработано: cw1399.json - 28 зубов
# Обработано: cw1400.json - 32 зубов
# Обработано: cw1401.json - 29 зубов
# Обработано: cw1402.json - 30 зубов
# Обработано: cw1403.json - 31 зубов
# Обработано: cw1404.json - 30 зубов
# Обработано: cw1405.json - 31 зубов
# Обработано: cw1406.json - 32 зубов
# Обработано: cw1407.json - 30 зубов
# Обработано: cw1408.json - 31 зубов
# Обработано: cw1409.json - 32 зубов
# Обработано: cw1410.json - 30 зубов
# Обработано: cw1411.json - 30 зубов
# Обработано: cw1412.json - 32 зубов
# Обработано: cw1413.json - 32 зубов
# Обработано: cw1414.json - 26 зубов
# Обработано: cw1415.json - 29 зубов
# Обработано: cw1416.json - 31 зубов
# Обработано: cw1417.json - 20 зубов
# Обработано: cw1418.json - 31 зубов
# Обработано: cw1419.json - 28 зубов
# Обработано: cw1420.json - 32 зубов
# Обработано: cw1421.json - 26 зубов
# Обработано: cw1422.json - 31 зубов
# Обработано: cw1423.json - 32 зубов
# Обработано: cw1424.json - 30 зубов
# Обработано: cw1425.json - 32 зубов
# Обработано: cw1426.json - 30 зубов
# Обработано: cw1427.json - 32 зубов
# Обработано: cw1428.json - 30 зубов
# Обработано: cw1429.json - 30 зубов
# Обработано: cw1430.json - 30 зубов
# Обработано: cw1431.json - 30 зубов
# Обработано: cw1432.json - 32 зубов
# Обработано: cw1433.json - 29 зубов
# Обработано: cw1434.json - 30 зубов
# Обработано: cw1435.json - 24 зубов
# Обработано: cw1436.json - 30 зубов
# Обработано: cw1437.json - 31 зубов
# Обработано: cw1438.json - 31 зубов
# Обработано: cw1439.json - 28 зубов
# Обработано: cw1440.json - 31 зубов
# Обработано: cw1441.json - 31 зубов
# Обработано: cw1442.json - 26 зубов
# Обработано: cw1443.json - 32 зубов
# Обработано: cw1444.json - 32 зубов
# Обработано: cw1445.json - 20 зубов
# Обработано: cw1446.json - 32 зубов
# Обработано: cw1447.json - 32 зубов
# Обработано: cw1448.json - 32 зубов
# Обработано: cw1449.json - 32 зубов
# Обработано: cw1450.json - 28 зубов
# Обработано: cw1451.json - 28 зубов
# Обработано: cw1452.json - 32 зубов
# Обработано: cw1453.json - 29 зубов
# Обработано: cw1454.json - 32 зубов
# Обработано: cw1455.json - 32 зубов
# Обработано: cw1456.json - 32 зубов
# Обработано: cw1457.json - 19 зубов
# Обработано: cw1458.json - 32 зубов
# Обработано: cw1459.json - 25 зубов
# Обработано: cw1460.json - 32 зубов
# Обработано: cw1461.json - 30 зубов
# Обработано: cw1462.json - 32 зубов
# Обработано: cw1463.json - 32 зубов
# Обработано: cw1464.json - 32 зубов
# Обработано: cw1465.json - 28 зубов
# Обработано: cw1466.json - 32 зубов
# Обработано: cw1467.json - 29 зубов
# Обработано: cw1468.json - 32 зубов
# Обработано: cw1469.json - 30 зубов
# Обработано: cw1470.json - 22 зубов
# Обработано: cw1471.json - 32 зубов
# Обработано: cw1472.json - 32 зубов
# Обработано: cw1473.json - 30 зубов
# Обработано: cw1474.json - 31 зубов
# Обработано: cw1475.json - 32 зубов
# Обработано: cw1476.json - 32 зубов
# Обработано: cw1477.json - 30 зубов
# Обработано: cw1478.json - 32 зубов
# Обработано: cw1479.json - 30 зубов
# Обработано: cw1480.json - 32 зубов
# Обработано: cw1481.json - 32 зубов
# Обработано: cw1482.json - 24 зубов
# Обработано: cw1483.json - 32 зубов
# Обработано: cw1484.json - 31 зубов
# Обработано: cw1485.json - 29 зубов
# Обработано: cw1486.json - 29 зубов
# Обработано: cw1487.json - 30 зубов
# Обработано: cw1488.json - 31 зубов
# Обработано: cw1490.json - 26 зубов
# Обработано: cw1491.json - 29 зубов
# Обработано: cw1492.json - 24 зубов
# Обработано: cw1493.json - 32 зубов
# Обработано: cw1494.json - 32 зубов
# Обработано: cw1495.json - 32 зубов
# Обработано: cw1496.json - 32 зубов
# Обработано: cw1497.json - 32 зубов
# Обработано: cw1498.json - 32 зубов
# Обработано: cw1499.json - 31 зубов
# Обработано: cw1500.json - 7 зубов
# Обработано: cw1501.json - 7 зубов
# Обработано: cw1502.json - 7 зубов
# Обработано: cw1503.json - 32 зубов
# Обработано: cw1504.json - 25 зубов
# Обработано: cw1505.json - 32 зубов
# Обработано: cw1506.json - 26 зубов
# Обработано: cw1508.json - 27 зубов
# Обработано: cw1509.json - 27 зубов
# Обработано: cw1510.json - 30 зубов
# Обработано: cw1511.json - 30 зубов
# Обработано: cw1512.json - 28 зубов
# Обработано: cw1513.json - 32 зубов
# Обработано: cw1514.json - 32 зубов
# Обработано: cw1515.json - 29 зубов
# Обработано: cw1516.json - 30 зубов
# Обработано: cw1517.json - 32 зубов
# Обработано: cw1518.json - 32 зубов
# Обработано: cw1519.json - 32 зубов
# Обработано: cw1520.json - 32 зубов
# Обработано: cw1521.json - 22 зубов
# Обработано: cw1522.json - 30 зубов
# Обработано: cw1523.json - 31 зубов
# Обработано: cw1524.json - 28 зубов
# Обработано: cw1525.json - 20 зубов
# Обработано: cw1526.json - 29 зубов
# Обработано: cw1527.json - 29 зубов
# Обработано: cw1528.json - 32 зубов
# Обработано: cw1529.json - 26 зубов
# Обработано: cw1530.json - 32 зубов
# Обработано: cw1531.json - 32 зубов
# Обработано: cw1532.json - 32 зубов
# Обработано: cw1533.json - 30 зубов
# Обработано: cw1534.json - 31 зубов
# Обработано: cw1535.json - 30 зубов
# Обработано: cw1536.json - 15 зубов
# Обработано: cw1537.json - 23 зубов
# Обработано: cw1538.json - 31 зубов
# Обработано: cw1539.json - 31 зубов
# Обработано: cw1540.json - 30 зубов
# Обработано: cw1541.json - 30 зубов
# Обработано: cw1542.json - 31 зубов
# Обработано: cw1543.json - 31 зубов
# Обработано: cw1544.json - 23 зубов
# Обработано: cw1545.json - 28 зубов
# Обработано: cw1546.json - 27 зубов
# Обработано: cw1547.json - 30 зубов
# Обработано: cw1548.json - 31 зубов
# Обработано: cw1549.json - 30 зубов
# Обработано: cw1550.json - 31 зубов
# Обработано: cw1551.json - 30 зубов
# Обработано: cw1552.json - 29 зубов
# Обработано: cw1553.json - 29 зубов
# Обработано: cw1554.json - 22 зубов
# Обработано: cw1555.json - 21 зубов
# Обработано: cw1556.json - 31 зубов
# Обработано: cw1557.json - 28 зубов
# Обработано: cw1558.json - 32 зубов
# Обработано: cw1559.json - 32 зубов
# Обработано: cw1560.json - 30 зубов
# Обработано: cw1561.json - 32 зубов
# Обработано: cw1562.json - 29 зубов
# Обработано: cw1563.json - 30 зубов
# Обработано: cw1564.json - 28 зубов
# Обработано: cw1565.json - 32 зубов
# Обработано: cw1566.json - 30 зубов
# Обработано: cw1567.json - 30 зубов
# Обработано: cw1568.json - 32 зубов
# Обработано: cw1569.json - 31 зубов
# Обработано: cw1570.json - 32 зубов
# Обработано: cw1571.json - 32 зубов
# Обработано: cw1572.json - 25 зубов
# Обработано: cw1574.json - 32 зубов
# Обработано: cw1575.json - 30 зубов
# Обработано: cw1576.json - 30 зубов
# Обработано: cw1577.json - 31 зубов
# Обработано: cw1578.json - 28 зубов
# Обработано: cw1579.json - 28 зубов
# Обработано: cw1580.json - 32 зубов
# Обработано: cw1581.json - 30 зубов
# Обработано: cw1582.json - 31 зубов
# Обработано: cw1583.json - 29 зубов
# Обработано: cw1584.json - 32 зубов
# Обработано: cw1585.json - 29 зубов
# Обработано: cw1586.json - 27 зубов
# Обработано: cw1587.json - 27 зубов
# Обработано: cw1588.json - 32 зубов
# Обработано: cw1589.json - 32 зубов
# Обработано: cw1590.json - 32 зубов
# Обработано: cw1591.json - 29 зубов
# Обработано: cw1592.json - 31 зубов
# Обработано: cw1593.json - 30 зубов
# Обработано: cw1594.json - 32 зубов
# Обработано: cw1595.json - 29 зубов
# Обработано: cw1596.json - 30 зубов
# Обработано: cw1597.json - 29 зубов
# Обработано: cw1598.json - 32 зубов
# Обработано: cw1599.json - 22 зубов
# Обработано: cw1600.json - 26 зубов
# Обработано: cw1601.json - 26 зубов
# Обработано: cw1602.json - 33 зубов
# Обработано: cw1603.json - 32 зубов
# Обработано: cw1604.json - 28 зубов
# Обработано: cw1605.json - 32 зубов
# Обработано: cw1606.json - 32 зубов
# Обработано: cw1607.json - 31 зубов
# Обработано: cw1608.json - 30 зубов
# Обработано: cw1609.json - 32 зубов
# Обработано: cw1610.json - 29 зубов
# Обработано: cw1611.json - 28 зубов
# Обработано: cw1612.json - 32 зубов
# Обработано: cw1613.json - 30 зубов
# Обработано: cw1614.json - 31 зубов
# Обработано: cw1615.json - 28 зубов
# Обработано: cw1616.json - 32 зубов
# Обработано: cw1617.json - 29 зубов
# Обработано: cw1618.json - 30 зубов
# Обработано: cw1619.json - 32 зубов
# Обработано: cw1620.json - 29 зубов
# Обработано: cw1621.json - 30 зубов
# Обработано: cw1622.json - 26 зубов
# Обработано: cw1623.json - 32 зубов
# Обработано: cw1624.json - 32 зубов
# Обработано: cw1625.json - 32 зубов
# Обработано: cw1626.json - 29 зубов
# Обработано: cw1627.json - 32 зубов
# Обработано: cw1628.json - 30 зубов
# Обработано: cw1629.json - 31 зубов
# Обработано: cw1630.json - 29 зубов
# Обработано: cw1631.json - 31 зубов
# Обработано: cw1632.json - 27 зубов
# Обработано: cw1633.json - 29 зубов
# Обработано: cw1635.json - 28 зубов
# Обработано: cw1636.json - 31 зубов
# Обработано: cw1637.json - 32 зубов
# Обработано: cw1638.json - 29 зубов
# Обработано: cw1639.json - 30 зубов
# Обработано: cw1640.json - 29 зубов
# Обработано: cw1641.json - 32 зубов
# Обработано: cw1642.json - 32 зубов
# Обработано: cw1643.json - 29 зубов
# Обработано: cw1644.json - 31 зубов
# Обработано: cw1645.json - 29 зубов
# Обработано: cw1646.json - 30 зубов
# Обработано: cw1647.json - 32 зубов
# Обработано: cw1648.json - 29 зубов
# Обработано: cw1649.json - 29 зубов
# Обработано: cw1650.json - 31 зубов
# Обработано: cw1651.json - 32 зубов
# Обработано: cw1652.json - 32 зубов
# Обработано: cw1653.json - 30 зубов
# Обработано: cw1654.json - 32 зубов
# Обработано: cw1655.json - 31 зубов
# Обработано: cw1656.json - 29 зубов
# Обработано: cw1657.json - 26 зубов
# Обработано: cw1658.json - 32 зубов
# Обработано: cw1659.json - 30 зубов
# Обработано: cw1660.json - 27 зубов
# Обработано: cw1661.json - 18 зубов
# Обработано: cw1662.json - 30 зубов
# Обработано: cw1663.json - 30 зубов
# Обработано: cw1664.json - 30 зубов
# Обработано: cw1665.json - 28 зубов
# Обработано: cw1666.json - 30 зубов
# Обработано: cw1667.json - 32 зубов
# Обработано: cw1668.json - 27 зубов
# Обработано: cw1669.json - 28 зубов
# Обработано: cw1670.json - 29 зубов
# Обработано: cw1671.json - 32 зубов
# Обработано: cw1672.json - 29 зубов
# Обработано: cw1673.json - 29 зубов
# Обработано: cw1674.json - 28 зубов
# Обработано: cw1675.json - 29 зубов
# Обработано: cw1676.json - 32 зубов
# Обработано: cw1677.json - 28 зубов
# Обработано: cw1678.json - 28 зубов
# Обработано: cw1679.json - 30 зубов
# Обработано: cw1680.json - 32 зубов
# Обработано: cw1681.json - 31 зубов
# Обработано: cw1682.json - 32 зубов
# Обработано: cw1683.json - 31 зубов
# Обработано: cw1684.json - 32 зубов
# Обработано: cw1685.json - 31 зубов
# Обработано: cw1686.json - 32 зубов
# Обработано: cw1688.json - 30 зубов
# Обработано: cw1689.json - 29 зубов
# Обработано: cw1690.json - 32 зубов
# Обработано: cw1691.json - 27 зубов
# Обработано: cw1692.json - 30 зубов
# Обработано: cw1693.json - 32 зубов
# Обработано: cw1694.json - 31 зубов
# Обработано: cw1695.json - 32 зубов
# Обработано: cw1696.json - 32 зубов
# Обработано: cw1697.json - 32 зубов
# Обработано: cw1698.json - 32 зубов
# Обработано: cw1699.json - 32 зубов
# Обработано: cw1700.json - 31 зубов
# Обработано: cw7300.json - 32 зубов
# Обработано: cw7301.json - 31 зубов
# Обработано: cw7302.json - 32 зубов
# Обработано: cw7303.json - 29 зубов
# Обработано: cw7304.json - 29 зубов
# Обработано: cw7305.json - 32 зубов
# Обработано: cw7306.json - 31 зубов
# Обработано: cw7307.json - 28 зубов
# Обработано: cw7308.json - 30 зубов
# Обработано: cw7309.json - 32 зубов
# Обработано: cw7310.json - 30 зубов
# Обработано: cw7311.json - 31 зубов
# Обработано: cw7312.json - 31 зубов
# Обработано: cw7313.json - 32 зубов
# Обработано: cw7314.json - 27 зубов
# Обработано: cw7315.json - 32 зубов
# Обработано: cw7316.json - 30 зубов
# Обработано: cw7317.json - 31 зубов
# Обработано: cw7318.json - 32 зубов
# Обработано: cw7319.json - 30 зубов
# Обработано: cw7320.json - 31 зубов
# Обработано: cw7321.json - 27 зубов
# Обработано: cw7322.json - 32 зубов
# Обработано: cw7323.json - 28 зубов
# Обработано: cw7324.json - 32 зубов
# Обработано: cw7325.json - 30 зубов
# Обработано: cw7326.json - 31 зубов
# Обработано: cw7327.json - 32 зубов
# Обработано: cw7328.json - 28 зубов
# Обработано: cw7329.json - 31 зубов
# Обработано: cw7330.json - 30 зубов
# Обработано: cw7331.json - 28 зубов
# Обработано: cw7332.json - 26 зубов
# Обработано: cw7333.json - 31 зубов
# Обработано: cw7334.json - 32 зубов
# Обработано: cw7335.json - 29 зубов
# Обработано: cw7336.json - 32 зубов
# Обработано: cw7337.json - 31 зубов
# Обработано: cw7338.json - 32 зубов
# Обработано: cw7339.json - 31 зубов
# Обработано: cw7340.json - 30 зубов
# Обработано: cw7341.json - 23 зубов
# Обработано: cw7342.json - 32 зубов
# Обработано: cw7343.json - 29 зубов
# Обработано: cw7344.json - 31 зубов
# Обработано: cw7345.json - 32 зубов
# Обработано: cw7346.json - 31 зубов
# Обработано: cw7347.json - 29 зубов
# Обработано: cw7348.json - 30 зубов
# Обработано: cw7349.json - 32 зубов
# Обработано: cw7350.json - 29 зубов
# Обработано: cw7351.json - 31 зубов
# Обработано: cw7352.json - 31 зубов
# Обработано: cw7353.json - 31 зубов
# Обработано: cw7354.json - 26 зубов
# Обработано: cw7355.json - 32 зубов
# Обработано: cw7356.json - 25 зубов
# Обработано: cw7357.json - 31 зубов
# Обработано: cw7358.json - 26 зубов
# Обработано: cw7359.json - 32 зубов
# Обработано: cw7360.json - 32 зубов
# Обработано: cw7361.json - 28 зубов
# Обработано: cw7362.json - 30 зубов
# Обработано: cw7363.json - 30 зубов
# Обработано: cw7364.json - 29 зубов
# Обработано: cw7365.json - 24 зубов
# Обработано: cw7366.json - 19 зубов
# Обработано: cw7367.json - 28 зубов
# Обработано: cw7368.json - 28 зубов
# Обработано: cw7369.json - 7 зубов
# Обработано: cw7370.json - 7 зубов
# Обработано: cw7371.json - 27 зубов
# Обработано: cw7372.json - 32 зубов
# Обработано: cw7373.json - 32 зубов
# Обработано: cw7374.json - 28 зубов
# Обработано: cw7375.json - 31 зубов
# Обработано: cw7376.json - 31 зубов
# Обработано: cw7377.json - 30 зубов
# Обработано: cw7378.json - 31 зубов
# Обработано: cw7379.json - 31 зубов
# Обработано: cw7380.json - 30 зубов
# Обработано: cw7381.json - 32 зубов
# Обработано: cw7382.json - 30 зубов
# Обработано: cw7383.json - 28 зубов
# Обработано: cw7384.json - 30 зубов
# Обработано: cw7385.json - 32 зубов
# Обработано: cw7386.json - 29 зубов
# Обработано: cw7387.json - 28 зубов
# Обработано: cw7388.json - 32 зубов
# Обработано: cw7390.json - 28 зубов
# Обработано: cw7391.json - 33 зубов
# Обработано: cw7392.json - 25 зубов
# Обработано: cw7393.json - 16 зубов
# Обработано: cw7394.json - 27 зубов
# Обработано: cw7395.json - 30 зубов
# Обработано: cw7396.json - 32 зубов
# Обработано: cw7397.json - 29 зубов
# Обработано: cw7398.json - 24 зубов
# Обработано: cw7399.json - 31 зубов
# Обработано: cw7400.json - 30 зубов
# Обработано: cw7401.json - 24 зубов
# Обработано: cw7402.json - 32 зубов
# Обработано: cw7403.json - 29 зубов
# Обработано: cw7404.json - 30 зубов
# Обработано: cw7405.json - 29 зубов
# Обработано: cw7406.json - 28 зубов
# Обработано: cw7407.json - 29 зубов
# Обработано: cw7408.json - 31 зубов
# Обработано: cw7409.json - 28 зубов
# Обработано: cw7410.json - 31 зубов
# Обработано: cw7411.json - 32 зубов
# Обработано: cw7412.json - 30 зубов
# Обработано: cw7413.json - 30 зубов
# Обработано: cw7414.json - 27 зубов
# Обработано: cw7415.json - 32 зубов
# Обработано: cw7416.json - 32 зубов
# Обработано: cw7417.json - 30 зубов
# Обработано: cw7418.json - 32 зубов
# Обработано: cw7419.json - 25 зубов
# Обработано: cw7420.json - 29 зубов
# Обработано: cw7421.json - 30 зубов
# Обработано: cw7422.json - 31 зубов
# Обработано: cw7423.json - 7 зубов
# Обработано: cw7424.json - 29 зубов
# Обработано: cw7425.json - 32 зубов
# Обработано: cw7426.json - 31 зубов
# Обработано: cw7427.json - 31 зубов
# Обработано: cw7428.json - 26 зубов
# Обработано: cw7429.json - 31 зубов
# Обработано: cw7430.json - 19 зубов
# Обработано: cw7431.json - 30 зубов
# Обработано: cw7432.json - 32 зубов
# Обработано: cw7433.json - 28 зубов
#
# Всего собрано записей: 58269

# %%
df = pd.DataFrame(all_records)

print("\n" + "="*60)
print("СТАТИСТИКА ДАТАСЕТА")
print("="*60)

print(f"\nВсего зубов: {len(df)}")

print(f"\nРаспределение по номерам зубов:")
print(df['tooth_label'].value_counts().sort_index())

print(f"\nРаспределение по квадрантам:")
quadrant_names = {1: 'Upper-Right', 2: 'Upper-Left', 3: 'Lower-Left', 4: 'Lower-Right'}
for q in sorted(df['quadrant'].unique()):
    count = len(df[df['quadrant'] == q])
    print(f"  Квадрант {q} ({quadrant_names.get(q, 'Unknown')}): {count} зубов")

print(f"\nСтатистика признаков:")
print(df[['x_norm', 'y_norm', 'aspect_ratio', 'neighbours_right', 'neighbours_top']].describe())

print("\nПример данных (первые 10 записей):")
display(df.head(10))
# Out:
# ============================================================
# СТАТИСТИКА ДАТАСЕТА
# ============================================================
#
# Всего зубов: 58269
#
# Распределение по номерам зубов:
# tooth_label
# 11    1978
# 12    1993
# 13    2017
# 14    1924
# 15    1845
# 16    1795
# 17    1812
# 18    1113
# 21    1975
# 22    1996
# 23    2024
# 24    1931
# 25    1838
# 26    1790
# 27    1837
# 28    1115
# 31    1957
# 32    1963
# 33    2038
# 34    1967
# 35    1876
# 36    1713
# 37    1759
# 38    1273
# 41    1946
# 42    1971
# 43    2041
# 44    1980
# 45    1898
# 46    1708
# 47    1809
# 48    1334
# 91      53
# Name: count, dtype: int64
#
# Распределение по квадрантам:
#   Квадрант 1 (Upper-Right): 14689 зубов
#   Квадрант 2 (Upper-Left): 14654 зубов
#   Квадрант 3 (Lower-Left): 14397 зубов
#   Квадрант 4 (Lower-Right): 14529 зубов
#
# Статистика признаков:
#              x_norm        y_norm  aspect_ratio  neighbours_right  neighbours_top
# count  58269.000000  58269.000000  58269.000000      58269.000000    58269.000000
# mean       0.498682      0.508160      2.463617         13.928676       13.907858
# std        0.242613      0.221958      0.928761          8.569526        8.568567
# min        0.020650      0.042115      0.000000          0.000000        0.000000
# 25%        0.316529      0.295593      1.736364          7.000000        7.000000
# 50%        0.497402      0.482417      2.479592         14.000000       14.000000
# 75%        0.681293      0.736984      3.151813         21.000000       21.000000
# max        0.983437      0.990000      6.457627         35.000000       35.000000
#
# Пример данных (первые 10 записей):
#   tooth_label  quadrant    x_norm    y_norm  aspect_ratio  neighbours_right  neighbours_top
# 0          12         1  0.404161  0.284247      2.926829                20               4
# 1          13         1  0.329029  0.274829      1.829932                22               2
# 2          14         1  0.287817  0.327055      2.018349                24               7
# 3          15         1  0.240582  0.347603      2.288889                25               9
# 4          16         1  0.186372  0.386130      1.561983                27              14
# 5          17         1  0.118848  0.379281      1.916667                29              13
# 6          18         1  0.055445  0.404110      1.833333                31              15
# 7          42         4  0.455835  0.702055      2.000000                17              20
# 8          43         4  0.405395  0.764555      2.334124                19              23
# 9          44         4  0.354073  0.773973      2.975610                21              26

# %%
df.to_csv(OUTPUT_CSV, index=False, encoding='utf-8')

print(f"\n" + "="*60)
print("ДАТАСЕТ УСПЕШНО СОЗДАН!")
print("="*60)
print(f"\nФайл сохранен: {OUTPUT_CSV}")
print(f"Всего записей: {len(df)}")
print(f"Количество признаков: {len(df.columns) - 2}")
print(f"Признаки: {list(df.columns[:-2])}")
print(f"Целевая переменная: tooth_label")
print("="*60)

summary = {
    "total_teeth": len(df),
    "total_images": df['source_file'].nunique(),
    "label_distribution": df['tooth_label'].value_counts().to_dict(),
    "quadrant_distribution": df['quadrant'].value_counts().to_dict(),
    "features": list(df.columns[:-2]),
    "target": "tooth_label",
    "output_file": OUTPUT_CSV
}

summary_path = os.path.join(OUTPUT_DIR, "dataset_summary.json")
with open(summary_path, 'w', encoding='utf-8') as f:
    json.dump(summary, f, indent=2, ensure_ascii=False)

print(f"\nСводная статистика сохранена: {summary_path}")
# Out:
# ============================================================
# ДАТАСЕТ УСПЕШНО СОЗДАН!
# ============================================================
#
# Файл сохранен: ../experiments/results/classification_dataset\teeth_classification_dataset.csv
# Всего записей: 58269
# Количество признаков: 5
# Признаки: ['tooth_label', 'quadrant', 'x_norm', 'y_norm', 'aspect_ratio']
# Целевая переменная: tooth_label
# ============================================================
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\py39\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'source_file'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 15
#      10 print(f"Целевая переменная: tooth_label")
#      11 print("="*60)
#      13 summary = {
#      14     "total_teeth": len(df),
# ---> 15     "total_images": df['source_file'].nunique(),
#      16     "label_distribution": df['tooth_label'].value_counts().to_dict(),
#      17     "quadrant_distribution": df['quadrant'].value_counts().to_dict(),
#      18     "features": list(df.columns[:-2]),
#      19     "target": "tooth_label",
#      20     "output_file": OUTPUT_CSV
#      21 }
#      23 summary_path = os.path.join(OUTPUT_DIR, "dataset_summary.json")
#      24 with open(summary_path, 'w', encoding='utf-8') as f:
#
# File ~\anaconda3\envs\py39\lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File ~\anaconda3\envs\py39\lib\site-packages\pandas\core\indexes\base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'source_file'
